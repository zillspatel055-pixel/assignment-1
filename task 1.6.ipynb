# %%
insta_followers = {
    "alpha_boy" : 2579,

    "abchere" : 9395,

    "uiherugff" : 10000,

    "eyo8rh9rfyv" : 12000,

    "hro8fgyhd" : 15000

     
 }

print( insta_followers )
# Out:
# {'alpha_boy': 2579, 'abchere': 9395, 'uiherugff': 10000, 'eyo8rh9rfyv': 12000, 'hro8fgyhd': 15000}

# %%
insta_followers.update({
    "eyo8rh9rfyv" : 12050,
    "kgyyccuoy" : 15654

})

print( insta_followers )
# Out:
# {'alpha_boy': 2579, 'abchere': 9395, 'uiherugff': 10000, 'eyo8rh9rfyv': 12050, 'hro8fgyhd': 15000, 'kgyyccuoy': 15654}

# %%
insta_followers.pop("abchere")

print( insta_followers )
# Out:
# {'alpha_boy': 2579, 'uiherugff': 10000, 'eyo8rh9rfyv': 12050, 'hro8fgyhd': 15000, 'kgyyccuoy': 15654}

# %%
food_prices = {
    "pizza": 550,
    "tea": 50,
    "burger": 100,
    "noodles": 200,
    "soup": 150
}

for food, price in food_prices.items():
    if price > 200:
        print(food)
# Out:
# pizza

# %%
flipkart_users = {"rahul","ram","sita","gita","tapu"}  

myntra_users = {"rahul","ram","piya","gita","zills"} 


x = flipkart_users & myntra_users

print(x)
# Out:
# {'rahul', 'gita', 'ram'}

# %%
def get_unique_artists(spotify_playlist1, spotify_playlist2) :
    {
     
       spotify_playlist1 = set(input("Enter the name").split())
    
       spotify_playlist2 = set(input("Enter the name").split())

        
       y = spotify_playlist1 | spotify_playlist2

       print(y)

    
}


get_unique_artists(spotify_playlist1, spotify_playlist2)
# Out:
#   Cell In[24], line 4
#     spotify_playlist1 = set(input("Enter the name").split())
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
