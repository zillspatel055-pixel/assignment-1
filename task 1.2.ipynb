# %%
item_price = 500 
delivery_fee = 50
coupon_discount = 100

# prints the variabes
print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 500
# 50
# 100

# %%
x = int(input("Enter the price of your purchase :"))

# check the condition
if(x >= 1000 ) :
     print(f"Eligible for free delivery.")
else : 
     print(f"Dilvery charge apply.")
# Out:
# Enter the price of your purchase : 1200
# Eligible for free delivery.

# %%
team_name = "chennai super kings"
runs_scored = 1000  
overs_played = 100

print(team_name)
print(runs_scored)
print(overs_played)
# Out:
# chennai super kings
# 1000
# 100

# %%
print()
