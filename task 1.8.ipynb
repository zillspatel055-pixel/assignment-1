# %%
for i in range(5):
    x = input("Enter your favourite delivery app :")
# Out:
# Enter your i favourite delivery app : jc
# Enter your i favourite delivery app : jvkv
# Enter your i favourite delivery app : vkv
# Enter your i favourite delivery app :  jh k
# Enter your i favourite delivery app : hjvk

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
steps = [6500, 8200, 9500, 10500, 12000, 9800, 11000]

i = 0

while i < len(steps):
    if steps[i] > 10000:
        print("First day crossing 10,000 steps:", days[i])
        print("Steps:", steps[i])
        break
i += 1

# %%
ipl_teams = ["CSK", "Mumbai Indians", "RCB", "Gujarat Titans", "KKR", "Punjab Kings"]

for team in ipl_teams:
    if len(team) <= 6:
        continue
    print(team)
# Out:
# Mumbai Indians
# Gujarat Titans
# Punjab Kings

# %%
song_durations = [210, 185, 240, 195, 220]

for position, duration in enumerate(song_durations, start=1):
    print(f"Song {position}: {duration} seconds")
        print(
