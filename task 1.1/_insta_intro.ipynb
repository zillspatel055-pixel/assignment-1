# %%
print(f"My Name Is Zills Patel.")
# Out:
# My Name Is Zills Patel.

# %%
print(f"My favorite app is Youtube.")
# Out:
# My favorite app is Youtube.

# %%
print(f"Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!
