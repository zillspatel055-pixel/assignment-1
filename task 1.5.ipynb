# %%
playlist_ids  = [1, 2, 3, 4, 5]

print(playlist_ids )
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
playlist_ids  = [1, 2, 3, 4, 5]

playlist_ids.append(6)
playlist_ids.append(7)
print(playlist_ids )
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # playlist_ids  = [1, 2, 3, 4, 5]
# otherplaylist_id = [6, 7]
# playlist_ids.playlist_ids.extend(6)
#
# print(playlist_ids

# %%
playlist_ids  = [1, 2, 3, 4, 5]

playlist_ids.extend((6,7))

print(playlist_ids )
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
playlist_ids  = [1, 2, 3, 4, 5]

x = playlist_ids.pop()

print(playlist_ids )
print(f"The removed song id is : {x}")
# Out:
# [1, 2, 3, 4]
# The removed song id is : 5

# %%
insta_filters = ("Ludwig", "Lark", "Juno", "Clarendon")

insta_filters.append("abcd")


# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 insta_filters = ("Ludwig", "Lark", "Juno", "Clarendon")
#       2 
# ----> 3 insta_filters.append("abcd")

# AttributeError: 'tuple' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 insta_filters = ("Ludwig", "Lark", "Juno", "Clarendon")
#       2
# ----> 3 insta_filters.append("abcd")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
zomato_orders = ["Pizza", "Burger", "Pasta"]
# list is used becoz order keeps changing.
print("In zomato_orders List is used")
ipl_teams = (
    "CSK", "MI", "RCB", "KKR", "GT",
    "RR", "DC", "PBKS", "SRH", "LSG"
)
print("In ipl_teams Tuple is used")
# They are fixed.So tuple is used.
# Out:
# In zomato_orders List is used
# In ipl_teams Tuple is used
