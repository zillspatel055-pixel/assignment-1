# %%
min = int(input("Enter Your music listening mins :"))

if(min >=120):
    print("true music lover.")
else :
    print("Keep listening")
# Out:
# Enter Your music listening mins : 130
# true music lover.

# %%
total_amount = int(input("Enter your order amount :"))

if(total_amount > 300):

    print("eligible for free delivery.")

else : 
    print("Delivery charges apply")
# Out:
# Enter your order amount : 350
# eligible for free delivery.

# %%
total_amount = int(input("Enter your order amount :"))

if(total_amount > 2000):

    print("You get a 10% discount.")
elif(total_amount > 1000 and total_amount < 2000):
    print("You get a 5% discount.")
else : 
    print("No discount available.")
# Out:
# Enter your order amount : 1500
# You get a 5% discount.

# %%
points = int(input("Enter your IPL fantasy team points: "))


if points > 800:
    print("Champion")
else:
    if points >= 500:
        print("Top Performer")
    else:
        print("Keep Trying")
