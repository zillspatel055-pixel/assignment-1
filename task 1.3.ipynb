# %%
age = 18
height = 174.34
name = "zills"
account = True

if account : 
    print(f"you have spotify account.")
else : 
    ("you don't have spotify account.")


print(type(age))
print(type(height))
print(type(name))
print(type(account))
# Out:
# you have spotify account.
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
def total_cart_amount(prices):
    prices= []
    n = int(input("Enter the value of n : "))
    for i in range(n) :
        num = int(input("Enter the number :"))
        prices.append(num)
    total = 0
    for i in range(n) :
        total = total + prices[i]
    return total

prices = []
result = total_cart_amount(prices)
print(result)
# Out:
# Enter the value of n :  4
# Enter the number : 450
# Enter the number : 550
# Enter the number : 600
# Enter the number : 300
# 1900

# %%
score = str(input("Enter your score in cricket :"))

x = int(score)

if (x >= 50) :
    print(f"Half centuary !!")
else : 
     print(f"Keep going")
# Out:
# Enter your score in cricket : 56
# Half centuary !!
